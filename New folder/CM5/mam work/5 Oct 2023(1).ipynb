# %% [markdown]
# # Pandas

# %% [markdown]
# ## Pandas Library

# %%
# Importing required libraries
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Employee.csv') #Reading csv file

# %%
df #printing a dataset
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
print(df.to_string()) #Printing the complete details of dataset.
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# 0     Bachelors         2017  Bangalore            3   34    Male          No                          0           0
# 1     Bachelors         2013       Pune            1   28  Female          No                          3           1
# 2     Bachelors         2014  New Delhi            3   38  Female          No                          2           0
# 3       Masters         2016  Bangalore            3   27    Male          No                          5           1
# 4       Masters         2017       Pune            3   24    Male         Yes                          2           1
# 5     Bachelors         2016  Bangalore            3   22    Male          No                          0           0
# 6     Bachelors         2015  New Delhi            3   38    Male          No                          0           0
# ...

# %% [markdown]
# # Viewing and understanding the Data

# %%
# selecting starting 5 records of dataset
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.head(10) #selecting first 10 records from dataset
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
# Select last 5 records of dataset
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df.tail(2)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 4651  Bachelors         2012  Bangalore            3   30   Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33   Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4651                          2           0
# 4652                          4           0

# %%
# Understanding data using describe()
df.describe() #only works with a numaric data
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.describe(include=[int]) #Selecting the data from dataset by including specific datatype
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#Selecting the data from dataset by excluding specific datatype
df.describe(exclude=[int])
# Out:
#         Education       City Gender EverBenched
# count        4653       4653   4653        4653
# unique          3          3      2           2
# top     Bachelors  Bangalore   Male          No
# freq         3601       2228   2778        4175

# %%
df.describe().T
# Out:
#                             count         mean       std     min     25%  \
# JoiningYear                4653.0  2015.062970  1.863377  2012.0  2013.0
# PaymentTier                4653.0     2.698259  0.561435     1.0     3.0
# Age                        4653.0    29.393295  4.826087    22.0    26.0
# ExperienceInCurrentDomain  4653.0     2.905652  1.558240     0.0     2.0
# LeaveOrNot                 4653.0     0.343864  0.475047     0.0     0.0
#
#                               50%     75%     max
# JoiningYear                2015.0  2017.0  2018.0
# PaymentTier                   3.0     3.0     3.0
# Age                          28.0    32.0    41.0
# ExperienceInCurrentDomain     3.0     4.0     7.0
# LeaveOrNot                    0.0     1.0     1.0

# %%
#Understanding the dataset using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 254.5+ KB

# %%
# Getting the no of rows and columns of dataset 
df.shape
# Out:
# (4653, 9)

# %%
# getting a no of rows in dataset
df.shape[0] # in shape methode 0 indicates no of rows.
# Out:
# 4653

# %%
df.shape[1] # in shape method 1 indicates no of columns.
# Out:
# 9

# %%
#Get all the columns and its name from dataset
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
#convert columns into a list
list(df.columns)
# Out:
# ['Education',
#  'JoiningYear',
#  'City',
#  'PaymentTier',
#  'Age',
#  'Gender',
#  'EverBenched',
#  'ExperienceInCurrentDomain',
#  'LeaveOrNot']

# %%
#Selecting a specific column from dataset
df['Age']
# Out:
# 0       34
# 1       28
# 2       38
# 3       27
# 4       24
#         ..
# 4648    26
# 4649    37
# 4650    27
# 4651    30
# 4652    33
# Name: Age, Length: 4653, dtype: int64

# %%
#Display multiple columns from dataset
df[['Age','City','Gender']]
# Out:
#       Age       City  Gender
# 0      34  Bangalore    Male
# 1      28       Pune  Female
# 2      38  New Delhi  Female
# 3      27  Bangalore    Male
# 4      24       Pune    Male
# ...   ...        ...     ...
# 4648   26  Bangalore  Female
# 4649   37       Pune    Male
# 4650   27  New Delhi    Male
# 4651   30  Bangalore    Male
# 4652   33  Bangalore    Male
#
# [4653 rows x 3 columns]

# %%
#Display Single column type
type(df['City'])
# Out:
# pandas.core.series.Series

# %%
#Display Multiple Column types
type(df[['Age','City']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Featching specific rows
df.loc[]
# Out:
#   Cell In[33], line 2
#     df.loc[]
#            ^
# SyntaxError: invalid syntax

# %%
df.loc[0]
# Out:
# Education                    Bachelors
# JoiningYear                       2017
# City                         Bangalore
# PaymentTier                          3
# Age                                 34
# Gender                            Male
# EverBenched                         No
# ExperienceInCurrentDomain            0
# LeaveOrNot                           0
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Education                    Bachelors
# JoiningYear                       2013
# City                              Pune
# PaymentTier                          1
# Age                                 28
# Gender                          Female
# EverBenched                         No
# ExperienceInCurrentDomain            3
# LeaveOrNot                           1
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# Education                    Bachelors
# JoiningYear                       2015
# City                         Bangalore
# PaymentTier                          3
# Age                                 33
# Gender                            Male
# EverBenched                        Yes
# ExperienceInCurrentDomain            4
# LeaveOrNot                           0
# Name: 4652, dtype: object

# %%
df.iloc[:,0]
# Out:
# 0       Bachelors
# 1       Bachelors
# 2       Bachelors
# 3         Masters
# 4         Masters
#           ...
# 4648    Bachelors
# 4649      Masters
# 4650      Masters
# 4651    Bachelors
# 4652    Bachelors
# Name: Education, Length: 4653, dtype: object

# %%
#Checking for the missing values in dataframe
df.isnull()
# Out:
#       Education  JoiningYear   City  PaymentTier    Age  Gender  EverBenched  \
# 0         False        False  False        False  False   False        False
# 1         False        False  False        False  False   False        False
# 2         False        False  False        False  False   False        False
# 3         False        False  False        False  False   False        False
# 4         False        False  False        False  False   False        False
# ...         ...          ...    ...          ...    ...     ...          ...
# 4648      False        False  False        False  False   False        False
# 4649      False        False  False        False  False   False        False
# 4650      False        False  False        False  False   False        False
# 4651      False        False  False        False  False   False        False
# 4652      False        False  False        False  False   False        False
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
# checing total null values in each column
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
# to get the total missing values in dataframe
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Grouping in Pandas

# %%
a=df.groupby(by=['Age']) # Grouping the data

# %%
a.first() #To view the results of grouping
# Out:
#      Education  JoiningYear       City  PaymentTier  Gender EverBenched  \
# Age
# 22   Bachelors         2016  Bangalore            3    Male          No
# 23   Bachelors         2016       Pune            3    Male          No
# 24     Masters         2017       Pune            3    Male         Yes
# 25         PHD         2013  New Delhi            3    Male          No
# 26   Bachelors         2018  Bangalore            3    Male          No
# 27     Masters         2016  Bangalore            3    Male          No
# 28   Bachelors         2013       Pune            1  Female          No
# 29   Bachelors         2017  Bangalore            1    Male          No
# 30   Bachelors         2015       Pune            2  Female          No
# 31   Bachelors         2013       Pune            2  Female          No
# 32   Bachelors         2018       Pune            3    Male         Yes
# 33   Bachelors         2017  Bangalore            3    Male          No
# ...

# %%
x=df.groupby(['Age','Gender'])

# %%
x.first()
# Out:
#             Education  JoiningYear       City  PaymentTier EverBenched  \
# Age Gender
# 22  Female  Bachelors         2016  New Delhi            2          No
#     Male    Bachelors         2016  Bangalore            3          No
# 23  Female  Bachelors         2014  Bangalore            3          No
#     Male    Bachelors         2016       Pune            3          No
# 24  Female  Bachelors         2015  Bangalore            3          No
#     Male      Masters         2017       Pune            3         Yes
# 25  Female  Bachelors         2014       Pune            3          No
#     Male          PHD         2013  New Delhi            3          No
# 26  Female  Bachelors         2015       Pune            2          No
#     Male    Bachelors         2018  Bangalore            3          No
# 27  Female  Bachelors         2015  Bangalore            3         Yes
#     Male      Masters         2016  Bangalore            3          No
# ...

# %%
x=df.groupby(['Age','Gender']).agg('min')

# %%
x
# Out:
#             Education  JoiningYear       City  PaymentTier EverBenched  \
# Age Gender
# 22  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            2          No
# 23  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            1          No
# 24  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            1          No
# 25  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            1          No
# 26  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            1          No
# 27  Female  Bachelors         2012  Bangalore            1          No
#     Male    Bachelors         2012  Bangalore            1          No
# ...

# %%
agg_functions= {
    'Age':
    ['sum','mean','median','min','max']
}

# %%
df.groupby(['Gender']).agg(agg_functions) #Viewing the Aggregate function with groupby method.
# Out:
#           Age
#           sum      mean median min max
# Gender
# Female  55155  29.41600   28.0  22  41
# Male    81612  29.37797   28.0  22  41

# %%
print(df.groupby(['Age','Gender']).groups)
# Out:
# {(22, 'Female'): [19, 25, 63, 4021, 4024, 4070, 4080, 4135, 4255, 4284, 4329, 4338, 4393, 4400, 4539, 4544, 4572, 4609, 4635], (22, 'Male'): [5, 91, 3991, 3993, 4025, 4048, 4069, 4098, 4119, 4144, 4154, 4185, 4225, 4234, 4248, 4286, 4305, 4318, 4325, 4357, 4358, 4377, 4381, 4436, 4472, 4491, 4530, 4536, 4561, 4626], (23, 'Female'): [45, 70, 76, 77, 4060, 4082, 4092, 4115, 4143, 4163, 4164, 4210, 4272, 4425, 4508, 4517, 4542, 4555, 4586, 4612], (23, 'Male'): [8, 27, 31, 41, 4011, 4028, 4046, 4054, 4084, 4112, 4147, 4188, 4211, 4214, 4218, 4221, 4308, 4314, 4316, 4375, 4404, 4413, 4443, 4512, 4540, 4550, 4563, 4607], (24, 'Female'): [68, 99, 141, 152, 154, 162, 178, 224, 236, 245, 254, 256, 284, 297, 308, 311, 322, 332, 335, 338, 341, 342, 363, 376, 389, 401, 428, 458, 473, 482, 492, 515, 521, 522, 561, 606, 608, 636, 641, 646, 663, 712, 721, 725, 730, 747, 765, 773, 795, 805, 806, 816, 830, 831, 882, 886, 888, 909, 911, 913, 920, 950, 956, 973, 990, 991, 1005, 1008, 1041, 1066, 1068, 
# ...

# %%
df.groupby('Education').sum()
# Out:
# C:\Users\malam\AppData\Local\Temp\ipykernel_14556\384043374.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Education').sum()
#            JoiningYear  PaymentTier     Age  ExperienceInCurrentDomain  \
# Education
# Bachelors      7255595         9914  105952                      10481
# Masters        1759799         2152   25571                       2518
# PHD             360694          489    5244                        521
#
#            LeaveOrNot
# Education
# Bachelors        1129
# Masters           426
# PHD                45

# %% [markdown]
# # Pandas Merging, Joining

# %%
#Creating a Employee data Dictionary
data1={
    'Name':['Riya','Pooja', 'nitin','padam'],
    'Age':[25,28,32,22],
    'Address':['Thane','Jaipur','Nagpur','Noida'],
    'Salary':[25000,40000,35000,30000],
    'Qualificatio':['Btech','Bsc','Bcom','Phd']
}

# %%
#Creating a Employee data Dictionary
data2={
    'Name':['Arti','Sapna', 'nitin','padam'],
    'Age':[27,28,30,22],
    'Address':['Thane','Jaipur','Bhopal','Patna'],
    'Salary':[25000,45000,38000,30000],
    'Qualificatio':['Msc','Bsc','Bcom','MCA']
}

# %%
#Converting Data into Dataframe
df1=pd.DataFrame(data1,index=[0,1,2,3])

# %%
#Converting Data into Dataframe
df2=pd.DataFrame(data2, index=[4,5,6,7])

# %%
print(df1, "\n\n", df2) #
# Out:
#     Name  Age Address  Salary Qualificatio
# 0   Riya   25   Thane   25000        Btech
# 1  Pooja   28  Jaipur   40000          Bsc
# 2  nitin   32  Nagpur   35000         Bcom
# 3  padam   22   Noida   30000          Phd
#
#      Name  Age Address  Salary Qualificatio
# 4   Arti   27   Thane   25000          Msc
# 5  Sapna   28  Jaipur   45000          Bsc
# 6  nitin   30  Bhopal   38000         Bcom
# 7  padam   22   Patna   30000          MCA

# %%
#Concatinating the dataframes
a=[df1,df2]
res=pd.concat(a)

# %%
res #Printing the result
# Out:
#     Name  Age Address  Salary Qualificatio
# 0   Riya   25   Thane   25000        Btech
# 1  Pooja   28  Jaipur   40000          Bsc
# 2  nitin   32  Nagpur   35000         Bcom
# 3  padam   22   Noida   30000          Phd
# 4   Arti   27   Thane   25000          Msc
# 5  Sapna   28  Jaipur   45000          Bsc
# 6  nitin   30  Bhopal   38000         Bcom
# 7  padam   22   Patna   30000          MCA

# %%
Data1={
    'Name':['Riya','Payal','Madhu','Neha'],
    'Address':['Kalyan','Dombivali','Shahad','Thakurli'],
    'Age':[25,33,32,30],
    'Qualification':['BA','MCOM','MSC','BSC'],
    'Mobile No':[98,94,97,96]
}

# %%
Data2={
    'Name':['Palak','Rahul','Madhu','Neha'],
    'Address':['Kalyan','Thane','Shahad','Kurla'],
    'Age':[27,33,31,30],
    'Qualification':['BCA','MCA','MSC','BSC'],
    'Salary':[1000,2000,3000,4000]
}

# %%
#Converting Data into Dataframe
df1=pd.DataFrame(Data1,index=[0,1,2,3])

# %%
#Converting Data into Dataframe
df2=pd.DataFrame(Data2, index=[4,5,6,7])

# %%
print(df1, "\n\n", df2)
# Out:
#     Name    Address  Age Qualification  Mobile No
# 0   Riya     Kalyan   25            BA         98
# 1  Payal  Dombivali   33          MCOM         94
# 2  Madhu     Shahad   32           MSC         97
# 3   Neha   Thakurli   30           BSC         96
#
#      Name Address  Age Qualification  Salary
# 4  Palak  Kalyan   27           BCA    1000
# 5  Rahul   Thane   33           MCA    2000
# 6  Madhu  Shahad   31           MSC    3000
# 7   Neha   Kurla   30           BSC    4000

# %%
res=pd.concat([df1,df2], axis=1, join='outer')

# %%
res
# Out:
#     Name    Address   Age Qualification  Mobile No   Name Address   Age  \
# 0   Riya     Kalyan  25.0            BA       98.0    NaN     NaN   NaN
# 1  Payal  Dombivali  33.0          MCOM       94.0    NaN     NaN   NaN
# 2  Madhu     Shahad  32.0           MSC       97.0    NaN     NaN   NaN
# 3   Neha   Thakurli  30.0           BSC       96.0    NaN     NaN   NaN
# 4    NaN        NaN   NaN           NaN        NaN  Palak  Kalyan  27.0
# 5    NaN        NaN   NaN           NaN        NaN  Rahul   Thane  33.0
# 6    NaN        NaN   NaN           NaN        NaN  Madhu  Shahad  31.0
# 7    NaN        NaN   NaN           NaN        NaN   Neha   Kurla  30.0
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           BCA  1000.0
# 5           MCA  2000.0
# 6           MSC  3000.0
# 7           BSC  4000.0
